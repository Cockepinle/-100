# %% [markdown]
# Цель работы: необходимо реализовать базовый анализ датасета: вывести весь датасет и описать его, вывести размерноть массива, вывести наименование всех колонок, написать что они означают в датасете, вывести все уникальные значения,отсортировать по определенным параметрам, удалить ненужные столбцы или строчки, заменить определенные значения в датасете , удалить дубликаты, провести анализ с помощью функций info, провести анализ с помощью функций describe, провести выборку данных по строкам и столбцам с помощью loc, сохранить новый датасет, сделать вывод по каждому пункту и описать все.

# %%
import pandas as pd
import numpy as np
waterQuality1 = pd.read_csv("waterQuality1.csv") 
waterQuality1
# Out:
#       aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 0          1.65    9.08     0.04    2.85    0.007        0.35      0.83
# 1          2.32   21.16     0.01    3.31    0.002        5.28      0.68
# 2          1.01   14.02     0.04    0.58    0.008        4.24      0.53
# 3          1.36   11.33     0.04    2.96    0.001        7.23      0.03
# 4          0.92   24.33     0.03    0.20    0.006        2.67      0.69
# ...         ...     ...      ...     ...      ...         ...       ...
# 7994       0.05    7.78     0.00    1.95    0.040        0.10      0.03
# 7995       0.05   24.22     0.02    0.59    0.010        0.45      0.02
# 7996       0.09    6.85     0.00    0.61    0.030        0.05      0.05
# 7997       0.01      10     0.01    2.00    0.000        2.00      0.00
# 7998       0.04    6.85     0.01    0.70    0.030        0.05      0.01
#
#       copper  flouride  bacteria  ...   lead  nitrates  nitrites  mercury  \
# ...

# %% [markdown]
# 1. Выводим весь датасет. В данном датасете (количество компонентов в воде) находятся следующие данные: алюминий, аммиак, мышьяк, барий, кадмий, хлорамин, бактерии, фторид, хром, медь, нитраты, свинец, нитриты , перхлорат, ртуть, радий, селен, серебро, уран, безопасность (количсетво данных веществ в воде).

# %%
waterQuality1.shape
# Out:
# (7999, 21)

# %% [markdown]
# 2. Выводим размерность массива

# %%
waterQuality1.columns
# Out:
# Index(['aluminium', 'ammonia', 'arsenic', 'barium', 'cadmium', 'chloramine',
#        'chromium', 'copper', 'flouride', 'bacteria', 'viruses', 'lead',
#        'nitrates', 'nitrites', 'mercury', 'perchlorate', 'radium', 'selenium',
#        'silver', 'uranium', 'is_safe'],
#       dtype='object')

# %% [markdown]
# 3. Выводим наименование всех колонок и то, что они значат: алюминий, аммиак, мышьяк, барий, кадмий, хлорамин, бактерии, фторид, хром, медь, нитраты, свинец, нитриты , перхлорат, ртуть, радий, селен, серебро, уран, безопасность.

# %%
waterQuality1["aluminium"].unique()
# Out:
# array([1.65, 2.32, 1.01, 1.36, 0.92, 0.94, 2.36, 3.93, 0.6 , 0.22, 3.27,
#        1.35, 1.88, 4.93, 2.89, 0.61, 3.47, 2.11, 4.88, 4.12, 0.68, 1.15,
#        0.27, 4.32, 3.31, 1.82, 3.42, 4.41, 4.57, 1.69, 1.87, 2.71, 1.63,
#        0.01, 4.49, 3.52, 4.35, 2.51, 2.34, 1.71, 3.45, 3.37, 3.13, 0.29,
#        1.51, 1.09, 2.68, 0.3 , 0.23, 2.55, 0.86, 0.24, 3.63, 3.26, 0.42,
#        0.77, 0.58, 3.82, 2.78, 3.62, 3.88, 4.64, 2.25, 0.54, 4.62, 2.5 ,
#        3.08, 3.03, 2.85, 1.38, 2.73, 3.02, 1.96, 2.35, 2.45, 2.67, 1.12,
#        3.3 , 0.43, 1.19, 0.85, 0.5 , 4.75, 1.89, 3.75, 3.32, 1.75, 2.66,
#        2.76, 2.63, 0.04, 0.88, 2.22, 4.91, 4.8 , 0.47, 1.62, 0.09, 4.66,
#        2.74, 1.79, 4.15, 3.78, 2.91, 4.3 , 3.24, 3.53, 3.04, 2.21, 2.47,
#        1.92, 1.22, 2.12, 4.19, 4.21, 4.07, 2.56, 3.55, 3.94, 0.8 , 2.59,
#        3.9 , 3.15, 0.18, 3.86, 1.25, 2.29, 0.07, 4.18, 4.34, 2.39, 0.9 ,
#        0.89, 2.4 , 3.69, 4.71, 3.36, 4.46, 4.5 , 0.57, 2.69, 2.17, 1.32,
# ...

# %%
waterQuality1["ammonia"].unique()
# Out:
# array(['9.08', '21.16', '14.02', ..., '2.78', '27.12', '10'], dtype=object)

# %%
waterQuality1["arsenic"].unique()
# Out:
# array([4.00e-02, 1.00e-02, 3.00e-02, 2.00e-02, 1.00e-03, 5.00e-02,
#        3.10e-01, 3.50e-01, 4.80e-01, 8.70e-01, 1.70e-01, 2.10e-01,
#        0.64, 0.57, 0.82, 0.87, 0.55, 0.14, 1.  , 0.47, 0.33, 0.09, 0.28,
#        0.19, 0.78, 0.02, 0.41, 0.46, 0.61, 0.62, 0.5 , 0.59, 0.15, 0.48,
#        0.68, 0.01, 0.73, 0.22, 0.21, 0.34, 0.43, 0.93, 0.66, 0.36, 0.17,
#        0.6 , 0.37, 0.29, 0.97, 0.95, 0.9 , 0.03, 0.4 , 0.94, 0.54, 0.81,
#        0.88, 0.  ])

# %%
waterQuality1["viruses"].unique()
# Out:
# array([0.   , 0.65 , 0.003, 0.71 , 0.001, 0.67 , 0.007, 0.005, 0.002,
#        0.83 , 0.008, 0.52 , 0.91 , 0.7  , 0.009, 0.89 , 0.85 , 0.75 ,
#        0.99 , 0.92 , 0.58 , 0.8  , 0.56 , 0.96 , 0.69 , 0.006, 0.77 ,
#        0.004, 0.63 , 0.86 , 0.79 , 0.84 , 0.98 , 0.74 , 0.76 , 0.51 ,
#        0.72 , 0.53 , 0.64 , 0.57 , 0.82 , 0.87 , 0.55 , 1.   , 0.78 ,
#        0.61 , 0.62 , 0.5  , 0.59 , 0.68 , 0.73 , 0.93 , 0.66 , 0.6  ,
#        0.97 , 0.95 , 0.9  , 0.94 , 0.54 , 0.81 , 0.88 ])

# %%
waterQuality1["lead"].unique()
# Out:
# array([0.054, 0.1  , 0.078, 0.016, 0.117, 0.135, 0.021, 0.197, 0.167,
#        0.109, 0.145, 0.011, 0.103, 0.101, 0.126, 0.017, 0.08 , 0.065,
#        0.071, 0.108, 0.086, 0.061, 0.114, 0.012, 0.031, 0.11 , 0.182,
#        0.049, 0.079, 0.013, 0.193, 0.091, 0.124, 0.107, 0.085, 0.146,
#        0.162, 0.048, 0.082, 0.141, 0.131, 0.069, 0.136, 0.166, 0.112,
#        0.169, 0.093, 0.025, 0.139, 0.184, 0.015, 0.09 , 0.068, 0.123,
#        0.177, 0.149, 0.062, 0.121, 0.105, 0.168, 0.137, 0.189, 0.095,
#        0.053, 0.113, 0.132, 0.175, 0.045, 0.036, 0.033, 0.191, 0.127,
#        0.032, 0.052, 0.047, 0.019, 0.129, 0.153, 0.147, 0.12 , 0.003,
#        0.16 , 0.18 , 0.072, 0.042, 0.092, 0.023, 0.185, 0.07 , 0.083,
#        0.155, 0.164, 0.17 , 0.043, 0.198, 0.194, 0.089, 0.044, 0.087,
#        0.122, 0.088, 0.158, 0.074, 0.148, 0.172, 0.041, 0.176, 0.038,
#        0.005, 0.181, 0.159, 0.05 , 0.156, 0.034, 0.138, 0.102, 0.064,
# ...

# %%
waterQuality1["nitrates"].unique()
# Out:
# array([16.08,  2.01, 14.16, ..., 12.76, 19.8 ,  0.  ])

# %%
waterQuality1["nitrites"].unique()
# Out:
# array([1.13, 1.93, 1.11, 1.29, 1.89, 1.78, 1.81, 1.84, 1.46, 1.25, 1.49,
#        1.95, 1.82, 1.08, 1.2 , 1.53, 1.22, 1.76, 1.41, 1.5 , 1.18, 1.74,
#        1.92, 1.07, 1.7 , 1.69, 1.43, 1.19, 1.55, 1.  , 1.27, 1.86, 1.35,
#        1.56, 1.83, 1.68, 1.73, 1.09, 1.28, 1.34, 1.21, 1.87, 1.45, 1.24,
#        1.79, 1.37, 1.48, 1.16, 1.4 , 1.57, 1.88, 1.59, 1.36, 1.9 , 1.06,
#        1.04, 1.58, 1.31, 1.38, 1.17, 1.3 , 1.02, 1.65, 1.47, 1.14, 1.51,
#        1.66, 1.99, 1.26, 1.91, 1.42, 1.33, 1.97, 1.03, 1.8 , 1.1 , 1.05,
#        1.64, 1.44, 1.15, 1.63, 1.72, 1.23, 1.85, 1.67, 1.6 , 1.54, 1.94,
#        1.12, 1.62, 1.52, 1.32, 1.98, 1.77, 1.61, 1.01, 1.75, 1.71, 2.  ,
#        1.96, 1.39, 2.12, 2.43, 2.03, 2.08, 2.06, 2.09, 2.19, 2.01, 2.27,
#        2.38, 2.02, 2.36, 2.44, 2.22, 2.21, 2.72, 2.25, 2.24, 2.28, 2.07,
#        2.2 , 2.62, 2.18, 2.04, 2.49, 2.29, 2.68, 2.56, 2.23, 2.58, 2.17,
#        2.05, 2.16, 2.53, 2.3 , 2.35, 2.11, 2.75, 2.26, 2.89, 2.52, 2.86,
# ...

# %%
waterQuality1["mercury"].unique()
# Out:
# array([0.007, 0.003, 0.006, 0.004, 0.001, 0.01 , 0.009, 0.008, 0.002,
#        0.005, 0.   ])

# %%
waterQuality1["perchlorate"].unique()
# Out:
# array([37.75, 32.26, 50.28, ..., 12.74,  9.42,  8.44])

# %%
waterQuality1["radium"].unique()
# Out:
# array([6.78, 3.21, 7.07, 1.72, 2.41, 5.42, 2.84, 7.24, 4.99, 0.08, 7.8 ,
#        1.3 , 1.97, 5.58, 4.33, 0.98, 6.89, 1.14, 1.  , 0.88, 3.05, 1.74,
#        0.9 , 3.22, 7.99, 0.49, 1.15, 3.29, 2.39, 4.55, 7.77, 2.21, 6.16,
#        1.71, 3.76, 6.15, 3.19, 0.5 , 4.7 , 6.14, 5.45, 0.37, 3.39, 2.18,
#        2.3 , 2.67, 4.27, 2.91, 4.12, 0.92, 1.53, 7.12, 5.63, 5.8 , 7.18,
#        4.87, 4.86, 4.34, 2.75, 3.81, 6.13, 4.91, 4.39, 6.65, 3.75, 0.63,
#        1.44, 7.4 , 7.81, 2.95, 1.29, 2.73, 6.35, 6.53, 7.02, 2.92, 2.35,
#        6.11, 0.86, 0.28, 5.14, 5.41, 4.15, 2.24, 6.46, 4.74, 1.08, 4.29,
#        6.98, 3.95, 3.32, 1.62, 7.6 , 6.6 , 1.2 , 6.36, 4.96, 5.77, 4.48,
#        6.74, 4.41, 6.28, 7.28, 1.45, 5.26, 2.2 , 0.25, 3.4 , 4.23, 4.14,
#        3.09, 2.58, 3.49, 1.39, 3.04, 0.68, 7.9 , 5.99, 4.8 , 5.11, 2.4 ,
#        2.53, 2.9 , 6.59, 3.42, 4.16, 1.23, 5.9 , 7.25, 6.42, 3.44, 1.67,
#        2.65, 6.2 , 6.66, 4.35, 3.24, 7.35, 3.23, 4.63, 6.49, 1.31, 3.72,
# ...

# %%
waterQuality1["selenium"].unique()
# Out:
# array([0.08, 0.07, 0.02, 0.1 , 0.03, 0.05, 0.09, 0.01, 0.06, 0.  , 0.04])

# %%
waterQuality1["silver"].unique()
# Out:
# array([0.34, 0.27, 0.44, 0.45, 0.06, 0.19, 0.24, 0.08, 0.25, 0.31, 0.33,
#        0.48, 0.38, 0.05, 0.47, 0.12, 0.4 , 0.41, 0.1 , 0.13, 0.01, 0.16,
#        0.18, 0.5 , 0.26, 0.17, 0.2 , 0.11, 0.3 , 0.37, 0.35, 0.04, 0.46,
#        0.  , 0.43, 0.42, 0.03, 0.28, 0.02, 0.21, 0.32, 0.09, 0.15, 0.14,
#        0.29, 0.22, 0.39, 0.36, 0.23, 0.07, 0.49])

# %%
waterQuality1["uranium"].unique()
# Out:
# array([0.02, 0.05, 0.01, 0.08, 0.07, 0.06, 0.03, 0.  , 0.04, 0.09])

# %%
waterQuality1["is_safe"].unique()
# Out:
# array(['1', '0', '#NUM!'], dtype=object)

# %% [markdown]
# 4. Выводим все уникальные значения в каждой из колонок в датасете.

# %%
waterQuality1.sort_values(by='uranium')
# Out:
#       aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 2118       0.13   16.35    0.030    2.90    0.008        5.14      0.29
# 5740       0.06    5.22    0.040    0.20    0.030        0.08      0.03
# 5736       0.10   24.24    0.080    0.40    0.020        0.17      0.01
# 2878       0.03   24.89    0.001    2.40    0.005        4.90      0.59
# 1842       0.55    8.06    0.960    2.72    0.040        0.66      0.88
# ...         ...     ...      ...     ...      ...         ...       ...
# 4493       0.06   23.89    0.050    0.32    0.060        0.33      0.09
# 4492       0.03   13.15    0.020    1.42    0.080        0.01      0.02
# 1272       3.78    4.59    0.370    0.47    0.040        1.99      0.69
# 7350       0.09   26.46    0.020    0.91    0.090        0.53      0.05
# 2120       0.29    5.43    0.040    2.34    0.002        4.13      0.70
#
#       copper  flouride  bacteria  ...   lead  nitrates  nitrites  mercury  \
# ...

# %% [markdown]
# 5. Отсортировка по параметру уран - "uranium", в котором произошла отсортировака по возрастаню от минимального значения - 0.0 до максимального значения - 0.09 .

# %%
waterQuality1.sort_values(by='silver', ascending=False)
# Out:
#       aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 2903       0.09    8.11     0.01    1.47    0.007        3.27      0.77
# 693        4.59    3.44     0.01    2.55    0.009        5.17      0.37
# 2122       0.15   29.72     0.02    1.40    0.008        3.71      0.47
# 3122       0.02   29.62     0.34    2.10    0.040        3.81      0.47
# 3564       0.08    0.41     0.57    2.66    0.080        1.17      0.33
# ...         ...     ...      ...     ...      ...         ...       ...
# 6731       0.02   10.42     0.04    2.48    0.090        0.20      0.00
# 4987       0.00      26     0.08    0.31    0.040        0.02      0.05
# 6737       0.01   18.88     0.02    0.99    0.060        0.00      0.04
# 2370       0.06   19.59     0.04    0.79    0.007        6.30      0.31
# 3999       0.05    8.83     0.00    0.97    0.080        0.09      0.01
#
#       copper  flouride  bacteria  ...   lead  nitrates  nitrites  mercury  \
# ...

# %% [markdown]
# 5. Отсортировка по параметру серебро - "silver", в котором произошла отсортировака по убыванию от максимального значения - 0.5 до минимального значения - 0.0

# %%
waterQuality1.drop(columns = ["nitrites"])
# Out:
#       aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 0          1.65    9.08     0.04    2.85    0.007        0.35      0.83
# 1          2.32   21.16     0.01    3.31    0.002        5.28      0.68
# 2          1.01   14.02     0.04    0.58    0.008        4.24      0.53
# 3          1.36   11.33     0.04    2.96    0.001        7.23      0.03
# 4          0.92   24.33     0.03    0.20    0.006        2.67      0.69
# ...         ...     ...      ...     ...      ...         ...       ...
# 7994       0.05    7.78     0.00    1.95    0.040        0.10      0.03
# 7995       0.05   24.22     0.02    0.59    0.010        0.45      0.02
# 7996       0.09    6.85     0.00    0.61    0.030        0.05      0.05
# 7997       0.01      10     0.01    2.00    0.000        2.00      0.00
# 7998       0.04    6.85     0.01    0.70    0.030        0.05      0.01
#
#       copper  flouride  bacteria  viruses   lead  nitrates  mercury  \
# ...

# %% [markdown]
# 6. Удаление колонки с именем "nitrites".

# %%
waterQuality1.drop([1,2], axis=0, inplace=True)
waterQuality1
# Out:
#       aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 0          1.65    9.08     0.04    2.85    0.007        0.35      0.83
# 3          1.36   11.33     0.04    2.96    0.001        7.23      0.03
# 4          0.92   24.33     0.03    0.20    0.006        2.67      0.69
# 5          0.94   14.47     0.03    2.88    0.003        0.80      0.43
# 6          2.36     5.6     0.01    1.35    0.004        1.28      0.62
# ...         ...     ...      ...     ...      ...         ...       ...
# 7994       0.05    7.78     0.00    1.95    0.040        0.10      0.03
# 7995       0.05   24.22     0.02    0.59    0.010        0.45      0.02
# 7996       0.09    6.85     0.00    0.61    0.030        0.05      0.05
# 7997       0.01      10     0.01    2.00    0.000        2.00      0.00
# 7998       0.04    6.85     0.01    0.70    0.030        0.05      0.01
#
#       copper  flouride  bacteria  ...   lead  nitrates  nitrites  mercury  \
# ...

# %% [markdown]
# 6. Удаление строк с индексами 1 и 2 во всм датасете.

# %%
waterQuality1=waterQuality1.replace({"perchlorate":9.12},10)
waterQuality1
# Out:
#       aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 0          1.65    9.08     0.04    2.85    0.007        0.35      0.83
# 3          1.36   11.33     0.04    2.96    0.001        7.23      0.03
# 4          0.92   24.33     0.03    0.20    0.006        2.67      0.69
# 5          0.94   14.47     0.03    2.88    0.003        0.80      0.43
# 6          2.36     5.6     0.01    1.35    0.004        1.28      0.62
# ...         ...     ...      ...     ...      ...         ...       ...
# 7994       0.05    7.78     0.00    1.95    0.040        0.10      0.03
# 7995       0.05   24.22     0.02    0.59    0.010        0.45      0.02
# 7996       0.09    6.85     0.00    0.61    0.030        0.05      0.05
# 7997       0.01      10     0.01    2.00    0.000        2.00      0.00
# 7998       0.04    6.85     0.01    0.70    0.030        0.05      0.01
#
#       copper  flouride  bacteria  ...   lead  nitrates  nitrites  mercury  \
# ...

# %% [markdown]
# 7.Заменена всех значений 9.12 в колонке perchlorate на значение 10.

# %%
waterQuality1.drop_duplicates()
# Out:
#       aluminium ammonia  arsenic  barium  cadmium  chloramine  chromium  \
# 0          1.65    9.08     0.04    2.85    0.007        0.35      0.83
# 3          1.36   11.33     0.04    2.96    0.001        7.23      0.03
# 4          0.92   24.33     0.03    0.20    0.006        2.67      0.69
# 5          0.94   14.47     0.03    2.88    0.003        0.80      0.43
# 6          2.36     5.6     0.01    1.35    0.004        1.28      0.62
# ...         ...     ...      ...     ...      ...         ...       ...
# 7994       0.05    7.78     0.00    1.95    0.040        0.10      0.03
# 7995       0.05   24.22     0.02    0.59    0.010        0.45      0.02
# 7996       0.09    6.85     0.00    0.61    0.030        0.05      0.05
# 7997       0.01      10     0.01    2.00    0.000        2.00      0.00
# 7998       0.04    6.85     0.01    0.70    0.030        0.05      0.01
#
#       copper  flouride  bacteria  ...   lead  nitrates  nitrites  mercury  \
# ...

# %% [markdown]
# 8. Удаление дубликатов во всем датасете, которое позволяет нам читабельность таблицы сделать лучше.

# %%
waterQuality1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7997 entries, 0 to 7998
# Data columns (total 21 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   aluminium    7997 non-null   float64
#  1   ammonia      7997 non-null   object
#  2   arsenic      7997 non-null   float64
#  3   barium       7997 non-null   float64
#  4   cadmium      7997 non-null   float64
#  5   chloramine   7997 non-null   float64
#  6   chromium     7997 non-null   float64
#  7   copper       7997 non-null   float64
#  8   flouride     7997 non-null   float64
#  9   bacteria     7997 non-null   float64
#  10  viruses      7997 non-null   float64
#  11  lead         7997 non-null   float64
#  12  nitrates     7997 non-null   float64
#  13  nitrites     7997 non-null   float64
#  14  mercury      7997 non-null   float64
#  15  perchlorate  7997 non-null   float64
#  16  radium       7997 non-null   float64
#  17  selenium     7997 non-null   float64
# ...

# %% [markdown]
# 9. Проведен анализ с помощью функций info, которая позволяет вывести общую информацию о дататайме, к примеру, функция вывела, что здесь находится 21 столбец, типы внесенных данных в таблицу и каково их кол-во, 7997 строк.

# %%
waterQuality1.describe()
# Out:
#          aluminium      arsenic       barium      cadmium   chloramine  \
# count  7997.000000  7997.000000  7997.000000  7997.000000  7997.000000
# mean      0.665908     0.161479     1.567620     0.042816     2.176185
# std       1.265162     0.252613     1.216037     0.036049     2.567010
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.040000     0.030000     0.560000     0.008000     0.100000
# 50%       0.070000     0.050000     1.190000     0.040000     0.530000
# 75%       0.280000     0.100000     2.480000     0.070000     4.240000
# max       5.050000     1.050000     4.940000     0.130000     8.680000
#
#           chromium       copper     flouride     bacteria      viruses  \
# count  7997.000000  7997.000000  7997.000000  7997.000000  7997.000000
# mean      0.247136     0.805973     0.771522     0.319657     0.328583
# std       0.270612     0.653560     0.435418     0.329492     0.378109
# ...

# %% [markdown]
# 10. Проведен анализ с помощью функций describe в датасете, который вывел для каждого столбца свои статические показатели, к примеру, видно, что максимальное значение - в столбце "aluminium" = 5.050000, а а минимально значение в данном столбце = 0.000000.

# %%
subset = waterQuality1.loc[[0, 4, 3], ['aluminium', 'arsenic', 'barium']]
subset
# Out:
#    aluminium  arsenic  barium
# 0       1.65     0.04    2.85
# 4       0.92     0.03    0.20
# 3       1.36     0.04    2.96

# %% [markdown]
# 11. Проведена выборка данных по строкам и столбцам с помощью loc, то есть в начале были указаны индексы строк =, которые необходимо вывести, а затем столбцы, чьи значения можно тнпнрь сравнить из новой таблицы.

# %%
waterQuality1.to_csv("waterQuality1_clear.csv")

# %% [markdown]
# 12. Сохранение нового датасета

# %% [markdown]
# Вывод: был реализован базовый анализ датасета: был выведен весь датасет и описан, выведена размерноть массива, выведены наименования всех колонок, написано что они означают в датасете, выведены все уникальные значения,отсортированы по определенным параметрам, удалены ненужные столбцы или строчки, заменены определенные значения в датасете, удалены дубликаты, проведен анализ с помощью функций info, проведен анализ с помощью функций describe, проведена выборку данных по строкам и столбцам с помощью loc, сохранен новый датасет, сделан вывод по каждому пункту и описать все.
